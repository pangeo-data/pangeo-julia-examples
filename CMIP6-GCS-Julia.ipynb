# %% [markdown]
# # Google Cloud CMIP6 Public Data: Basic Julia Example
#
# This notebooks shows how to query the catalog and load the data using Julia. Most of the syntax here comes directly from the [Zarr.jl docs](https://meggart.github.io/Zarr.jl/latest/s3examples/).

# %%
using Zarr, AWSCore
using DataFrames, CSV, Query
using CFTime, Dates
using PyPlot

# %%
aws_google = AWSCore.aws_config(creds=nothing, region="", service_host="googleapis.com", service_name="storage")
# Out:
# Dict{Symbol,Any} with 4 entries:
#   :service_name => "storage"
#   :service_host => "googleapis.com"
#   :creds        => nothing
#   :region       => ""

# %% [markdown]
# ## Browse Catalog
#
# The data catatalog is stored as a CSV file. Here we read it into a DataFrame

# %%
cmip6_base = S3Store("cmip6","", aws=aws_google, listversion=1)
df = CSV.read(IOBuffer(cmip6_base["cmip6-zarr-consolidated-stores.csv"]))
# Out:
# 188314×10 DataFrame. Omitted printing of 6 columns
# │ Row    │ activity_id │ institution_id │ source_id  │ experiment_id │
# │        │ String      │ String         │ String     │ String        │
# ├────────┼─────────────┼────────────────┼────────────┼───────────────┤
# │ 1      │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# │ 2      │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# │ 3      │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# │ 4      │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# │ 5      │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# │ 6      │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# │ 7      │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# │ 8      │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# │ 9      │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# │ 10     │ AerChemMIP  │ BCC            │ BCC-ESM1   │ piClim-CH4    │
# ⋮
# │ 188304 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188305 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188306 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188307 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188308 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188309 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188310 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188311 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188312 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188313 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │
# │ 188314 │ ScenarioMIP │ UA             │ MCM-UA-1-0 │ ssp585        │

# %% [markdown]
# The columns of the dataframe correspond to the CMI6 controlled vocabulary. A beginners' guide to these terms is available in [this document](https://docs.google.com/document/d/1yUx6jr9EdedCOLd--CPdTfGDwEwzPpCF6p1jRmqx-0Q).
#
# Here we filter the data to find monthly surface air temperature for historical experiments.

# %%
df_ta = df |> @filter(_.activity_id=="CMIP" && 
                      _.table_id=="Amon" &&
                      _.variable_id=="tas" &&
                      _.experiment_id=="historical") |> DataFrame
# Out:
# 213×10 DataFrame. Omitted printing of 5 columns
# │ Row │ activity_id │ institution_id │ source_id   │ experiment_id │ member_id │
# │     │ String      │ String         │ String      │ String        │ String    │
# ├─────┼─────────────┼────────────────┼─────────────┼───────────────┼───────────┤
# │ 1   │ CMIP        │ BCC            │ BCC-CSM2-MR │ historical    │ r1i1p1f1  │
# │ 2   │ CMIP        │ BCC            │ BCC-CSM2-MR │ historical    │ r2i1p1f1  │
# │ 3   │ CMIP        │ BCC            │ BCC-CSM2-MR │ historical    │ r3i1p1f1  │
# │ 4   │ CMIP        │ BCC            │ BCC-ESM1    │ historical    │ r1i1p1f1  │
# │ 5   │ CMIP        │ BCC            │ BCC-ESM1    │ historical    │ r2i1p1f1  │
# │ 6   │ CMIP        │ BCC            │ BCC-ESM1    │ historical    │ r3i1p1f1  │
# │ 7   │ CMIP        │ CAMS           │ CAMS-CSM1-0 │ historical    │ r1i1p1f1  │
# │ 8   │ CMIP        │ CAMS           │ CAMS-CSM1-0 │ historical    │ r2i1p1f1  │
# │ 9   │ CMIP        │ CCCma          │ CanESM5     │ historical    │ r10i1p1f1 │
# │ 10  │ CMIP        │ CCCma          │ CanESM5     │ historical    │ r10i1p2f1 │
# ⋮
# │ 203 │ CMIP        │ NCC            │ NorCPM1     │ historical    │ r17i1p1f1 │
# │ 204 │ CMIP        │ NCC            │ NorCPM1     │ historical    │ r23i1p1f1 │
# │ 205 │ CMIP        │ NCC            │ NorCPM1     │ historical    │ r26i1p1f1 │
# │ 206 │ CMIP        │ NUIST          │ NESM3       │ historical    │ r1i1p1f1  │
# │ 207 │ CMIP        │ NUIST          │ NESM3       │ historical    │ r2i1p1f1  │
# │ 208 │ CMIP        │ NUIST          │ NESM3       │ historical    │ r3i1p1f1  │
# │ 209 │ CMIP        │ NUIST          │ NESM3       │ historical    │ r4i1p1f1  │
# │ 210 │ CMIP        │ NUIST          │ NESM3       │ historical    │ r5i1p1f1  │
# │ 211 │ CMIP        │ SNU            │ SAM0-UNICON │ historical    │ r1i1p1f1  │
# │ 212 │ CMIP        │ UA             │ MCM-UA-1-0  │ historical    │ r1i1p1f1  │
# │ 213 │ CMIP        │ UA             │ MCM-UA-1-0  │ historical    │ r1i1p1f2  │

# %% [markdown]
# Now we do further filtering to find just the models from NCAR.

# %%
df_ta_ncar = df_ta |> @filter(_.institution_id=="NCAR") |> DataFrame
# Out:
# 16×10 DataFrame. Omitted printing of 6 columns
# │ Row │ activity_id │ institution_id │ source_id       │ experiment_id │
# │     │ String      │ String         │ String          │ String        │
# ├─────┼─────────────┼────────────────┼─────────────────┼───────────────┤
# │ 1   │ CMIP        │ NCAR           │ CESM2-FV2       │ historical    │
# │ 2   │ CMIP        │ NCAR           │ CESM2-WACCM-FV2 │ historical    │
# │ 3   │ CMIP        │ NCAR           │ CESM2-WACCM     │ historical    │
# │ 4   │ CMIP        │ NCAR           │ CESM2-WACCM     │ historical    │
# │ 5   │ CMIP        │ NCAR           │ CESM2-WACCM     │ historical    │
# │ 6   │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 7   │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 8   │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 9   │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 10  │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 11  │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 12  │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 13  │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 14  │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 15  │ CMIP        │ NCAR           │ CESM2           │ historical    │
# │ 16  │ CMIP        │ NCAR           │ CESM2           │ historical    │

# %% [markdown]
# ## Load Data
#
# Now we will load a single store using gcsfs, zarr, and xarray.

# %%
print(df_ta_ncar.zstore[end])
# the part we want
path = df_ta_ncar.zstore[end][12:end]
# Out:
# gs://cmip6/CMIP/NCAR/CESM2/historical/r9i1p1f1/Amon/tas/gn/
# "CMIP/NCAR/CESM2/historical/r9i1p1f1/Amon/tas/gn/"

# %%
zgroup = zopen(S3Store("cmip6", path, aws=aws_google, listversion=1))
# Out:
# ZarrGroup at S3 Object Storage
# Variables: lat time tas lat_bnds lon_bnds lon time_bnds

# %% [markdown]
# Plot the first value as a map.

# %%
lon = zgroup["lon"][:]
lat = zgroup["lat"][:]
tas = zgroup["tas"][:,:,1]
pcolormesh(lon, lat, transpose(tas))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.QuadMesh object at 0x13f6f1dd0>

# %% [markdown]
# Create a timeseries of global-average surface air temperature. For this we need the area weighting factor for each gridpoint.

# %%
df_area = df |> @filter(_.variable_id=="areacella" && _.source_id=="CESM2") |> DataFrame
# Out:
# 28×10 DataFrame. Omitted printing of 5 columns
# │ Row │ activity_id │ institution_id │ source_id │ experiment_id │ member_id │
# │     │ String      │ String         │ String    │ String        │ String    │
# ├─────┼─────────────┼────────────────┼───────────┼───────────────┼───────────┤
# │ 1   │ CFMIP       │ NCAR           │ CESM2     │ amip-4xCO2    │ r1i1p1f1  │
# │ 2   │ CFMIP       │ NCAR           │ CESM2     │ amip-future4K │ r1i1p1f1  │
# │ 3   │ CFMIP       │ NCAR           │ CESM2     │ amip-m4K      │ r1i1p1f1  │
# │ 4   │ CFMIP       │ NCAR           │ CESM2     │ amip-p4K      │ r1i1p1f1  │
# │ 5   │ CFMIP       │ NCAR           │ CESM2     │ aqua-4xCO2    │ r1i1p1f1  │
# │ 6   │ CFMIP       │ NCAR           │ CESM2     │ aqua-control  │ r1i1p1f1  │
# │ 7   │ CFMIP       │ NCAR           │ CESM2     │ aqua-p4K      │ r1i1p1f1  │
# │ 8   │ CMIP        │ NCAR           │ CESM2     │ 1pctCO2       │ r1i1p1f1  │
# │ 9   │ CMIP        │ NCAR           │ CESM2     │ amip          │ r1i1p1f1  │
# │ 10  │ CMIP        │ NCAR           │ CESM2     │ esm-piControl │ r1i1p1f1  │
# ⋮
# │ 18  │ CMIP        │ NCAR           │ CESM2     │ historical    │ r6i1p1f1  │
# │ 19  │ CMIP        │ NCAR           │ CESM2     │ historical    │ r7i1p1f1  │
# │ 20  │ CMIP        │ NCAR           │ CESM2     │ historical    │ r8i1p1f1  │
# │ 21  │ CMIP        │ NCAR           │ CESM2     │ historical    │ r9i1p1f1  │
# │ 22  │ CMIP        │ NCAR           │ CESM2     │ piControl     │ r1i1p1f1  │
# │ 23  │ LUMIP       │ NCAR           │ CESM2     │ hist-noLu     │ r1i1p1f1  │
# │ 24  │ LUMIP       │ NCAR           │ CESM2     │ hist-noLu     │ r2i1p1f1  │
# │ 25  │ LUMIP       │ NCAR           │ CESM2     │ hist-noLu     │ r3i1p1f1  │
# │ 26  │ ScenarioMIP │ NCAR           │ CESM2     │ ssp245        │ r1i1p1f1  │
# │ 27  │ ScenarioMIP │ NCAR           │ CESM2     │ ssp585        │ r1i1p1f1  │
# │ 28  │ ScenarioMIP │ NCAR           │ CESM2     │ ssp585        │ r2i1p1f1  │

# %%
path = df_area.zstore[1][12:end]
area = zopen(S3Store("cmip6", path, aws=aws_google, listversion=1))["areacella"][:, :]
# Out:
# 288×192 reshape(::Array{Union{Missing, Float32},2}, 288, 192) with eltype Union{Missing, Float32}:
#  2.99484e7  2.39575e8  4.79085e8  …  4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8  …  4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8  …  4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  ⋮                                ⋱             ⋮
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8  …  4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8  …  4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7
#  2.99484e7  2.39575e8  4.79085e8     4.79085e8  2.39575e8  2.99484e7

# %%
time_raw = zgroup["time"][:]
units = zgroup["time"].attrs["units"]
calendar = zgroup["time"].attrs["calendar"]
time = CFTime.timedecode(time_raw, units, calendar)
# Out:
# 1980-element Array{DateTimeNoLeap,1}:
#  DateTimeNoLeap(1850-01-15T12:00:00)
#  DateTimeNoLeap(1850-02-14T00:00:00)
#  DateTimeNoLeap(1850-03-15T12:00:00)
#  DateTimeNoLeap(1850-04-15T00:00:00)
#  DateTimeNoLeap(1850-05-15T12:00:00)
#  DateTimeNoLeap(1850-06-15T00:00:00)
#  DateTimeNoLeap(1850-07-15T12:00:00)
#  DateTimeNoLeap(1850-08-15T12:00:00)
#  DateTimeNoLeap(1850-09-15T00:00:00)
#  DateTimeNoLeap(1850-10-15T12:00:00)
#  DateTimeNoLeap(1850-11-15T00:00:00)
#  DateTimeNoLeap(1850-12-15T12:00:00)
#  DateTimeNoLeap(1851-01-15T12:00:00)
#  ⋮
#  DateTimeNoLeap(2014-01-15T12:00:00)
#  DateTimeNoLeap(2014-02-14T00:00:00)
#  DateTimeNoLeap(2014-03-15T12:00:00)
#  DateTimeNoLeap(2014-04-15T00:00:00)
#  DateTimeNoLeap(2014-05-15T12:00:00)
#  DateTimeNoLeap(2014-06-15T00:00:00)
#  DateTimeNoLeap(2014-07-15T12:00:00)
#  DateTimeNoLeap(2014-08-15T12:00:00)
#  DateTimeNoLeap(2014-09-15T00:00:00)
#  DateTimeNoLeap(2014-10-15T12:00:00)
#  DateTimeNoLeap(2014-11-15T00:00:00)
#  DateTimeNoLeap(2014-12-15T12:00:00)

# %%
tas_full = zgroup["tas"][:, :, :]
timeseries = dropdims(sum(tas_full .* area, dims=(1, 2)) / sum(area), dims=(1, 2))
# doesn't work
#plot(time, timeseries)
plot(timeseries)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x149e0ebd0>
